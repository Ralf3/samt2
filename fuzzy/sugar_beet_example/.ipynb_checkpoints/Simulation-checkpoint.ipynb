# %% [markdown]
# # Simulation of the Sugar Beet model

# %% [markdown]
# ## Load the modules

# %%
import sys
sys.path.append('../')
import Pyfuzzy as Fuzz
import numpy as np
import pylab as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Load the model

# %%
f1=Fuzz.read_model('zr_simple_t.fis')

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Define the Simulation

# %%
ZR=pd.ExcelFile('ZR_Daten_DDR_1976_1990.xlsx')
df=ZR.parse("Tabelle1")
pd.DataFrame({'NI': df['NI_6']+df['NI_7']+df['NI_8']+df['NI_9']}).describe()
# Out:
#                 NI
# count  4551.000000
# mean    222.603296
# std      77.191826
# min      67.900000
# 25%     170.400000
# 50%     217.300000
# 75%     269.700000
# max     482.900000
#
# [8 rows x 1 columns]

# %%
pd.DataFrame({'LT': df['LT_6']+df['LT_7']+df['LT_8']+df['LT_9']}).describe()
# Out:
#                 LT
# count  4551.000000
# mean     63.189695
# std       4.162295
# min      50.900000
# 25%      60.000000
# 50%      62.700000
# 75%      65.600000
# max      73.400000
#
# [8 rows x 1 columns]

# %%
az=[20,30,40,50,60,70]    # array of soil quality
NI=np.random.normal(222,77,1000)  # generate 1000 normal distributed NIs
LT=np.random.normal(63,4,1000)    # same for the temperature

# %% [markdown]
# ### Make the simulation

# %%
x=pd.DataFrame(np.zeros((1000,6)),columns=['20','30','40','50','60','70']) # a data frame to store the res
for k in az:
    res=[]
    for i in range(1000):     # use the 1000 samples
        val=f1.calc3(k,LT[i],NI[i])
        res.append(val)
    res=np.array(res)
    x[str(k)]=res
x.describe()
# Out:
#                 20           30           40           50           60  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    223.303216   251.383314   280.685501   306.200979   332.068547
# std      49.537362    44.178674    38.350402    37.695250    36.805358
# min      66.666664   116.666664   166.666672   216.666656   266.666656
# 25%     190.973717   226.028435   266.220924   285.254265   305.913040
# 50%     230.493011   255.974785   286.134537   305.997192   324.551727
# 75%     264.346458   283.504227   303.735863   331.126099   355.252525
# max     316.569977   388.883789   433.339447   433.337433   483.043304
#
#                 70
# count  1000.000000
# mean    332.068547
# std      36.805358
# min     266.666656
# 25%     305.913040
# 50%     324.551727
# 75%     355.252525
# max     483.043304
#
# [8 rows x 6 columns]

# %% [markdown]
# ### Repeat the simulation with changed NI and LI

# %%
NI-=50    # 50 mm less 
LT+=1     # 1 degree more
for k in az:
    res=[]
    for i in range(1000):     # use the 1000 samples
        val=f1.calc3(k,LT[i],NI[i])
        res.append(val)
    res=np.array(res)
    x[str(k)]=res
x.describe()
# Out:
#                 20           30           40           50           60  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    190.747730   221.713173   254.268038   281.023456   310.165253
# std      54.714692    49.835939    42.507111    36.579871    29.486781
# min      66.666664   116.666664   166.666656   216.666656   266.666656
# 25%     148.407238   189.476742   228.281544   254.978271   290.149902
# 50%     194.994064   228.586670   263.634430   284.357574   306.556274
# 75%     235.041584   260.973816   284.883659   305.325859   325.419418
# max     304.015289   345.676849   375.021179   397.220001   445.379242
#
#                 70
# count  1000.000000
# mean    310.165253
# std      29.486781
# min     266.666656
# 25%     290.149902
# 50%     306.556274
# 75%     325.419418
# max     445.379242
#
# [8 rows x 6 columns]
